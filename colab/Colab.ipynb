# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
PAT = # INSERT Personal Access Token

# %%
# !git clone -b mutag https://sergiogcharles:{PAT}@github.com/alessing/protein-func.git # CHANGE USERNAME
# Out:
# fatal: destination path 'protein-func' already exists and is not an empty directory.

# %%
# %ls
# Out:
# drive/  protein-func/  sample_data/

# %%
# %cd protein-func/
# Out:
# /content/protein-func

# %%
# !git branch
# Out:
# * mutag

# %%
# %ls
# Out:
# blog/                   environment.yml       model/         processing_scripts/
# condacolab_install.log  f1_plot.py            models/        README.md
# data/                   main.py               model_wrap.py  run_scripts/
# dataloader.py           make_hdf5_dataset.py  mutag.py       temp_proteins/

# %%
# Comment out this cell once kernel restarts
# !pip install -q condacolab
import condacolab
condacolab.install() # expect a kernel restart

# %%
import condacolab
# !mamba env update -n base -f environment.yml
# Out:
# [+] 0.0s
# [+] 0.1s
# pyg/linux-64 (chec..  ⣾  [+] 0.2s
# pyg/linux-64 (chec..  ⣾  pyg/linux-64 (check zst)
# [+] 0.0s
# pyg/noarch (check zst)                             Checked  0.1s
# [+] 0.0s
# pytorch/linux-64 (check zst)                       Checked  0.1s
# [+] 0.0s
# pytorch/noarch (check zst)                         Checked  0.1s
# [+] 0.0s
# nvidia/linux-64 (c..  ⣾  nvidia/linux-64 (check zst)
# [+] 0.0s
# nvidia/noarch (che..  ⣾  nvidia/noarch (check zst)
# [+] 0.0s
# pkgs/main/linux-64 (check zst)                     Checked  0.1s
# [+] 0.0s
# pkgs/main/noarch (check zst)                       Checked  0.0s
# [+] 0.0s
# pkgs/r/linux-64 (check zst)                        Checked  0.0s
# [+] 0.0s
# pkgs/r/noarch (check zst)                          Checked  0.0s
# [+] 0.0s
# pyg/linux-64      ⣾
# pyg/noarch        ⣾
# pytorch/linux-64  ⣾
# pytorch/noarch    ⣾
# nvidia/linux-64   ⣾  [+] 0.1s
# pyg/linux-64      ⣾
# pyg/noarch        ⣾
# pytorch/linux-64  ⣾
# ...

# %%
import torch

# %%
# !ls
# Out:
# blog			environment.yml       model	     processing_scripts
# condacolab_install.log	f1_plot.py	      models	     README.md
# data			main.py		      model_wrap.py  run_scripts
# dataloader.py		make_hdf5_dataset.py  mutag.py	     temp_proteins

# %%
# !python mutag.py --epochs 1000 --hidden_dim 128
# Out:
# Streaming output truncated to the last 5000 lines.
# Test Accuracy 0.7894736842105263
#  17% 167/1000 [00:25<02:04,  6.71it/s]Train MeanLoss 0.3764881706237793
# Train Accuracy 0.8533333333333334
# Val MeanLoss 0.3344306945800781
# Val Accuracy 0.8421052631578947
# Test MeanLoss 0.2882283329963684
# Test Accuracy 0.7368421052631579
#  17% 168/1000 [00:25<02:03,  6.73it/s]Train MeanLoss 0.31686729470888775
# Train Accuracy 0.8666666666666667
# Val MeanLoss 0.3407273590564728
# Val Accuracy 0.8421052631578947
# Test MeanLoss 0.3160708248615265
# Test Accuracy 0.7894736842105263
#  17% 169/1000 [00:25<02:03,  6.71it/s]Train MeanLoss 0.30697618405024213
# Train Accuracy 0.8666666666666667
# Val MeanLoss 0.3454039394855499
# Val Accuracy 0.8421052631578947
# Test MeanLoss 0.39409226179122925
# Test Accuracy 0.7894736842105263
#  17% 170/1000 [00:25<02:03,  6.72it/s]Train MeanLoss 0.3266218948364258
# Train Accuracy 0.8533333333333334
# Val MeanLoss 0.35105353593826294
# ...

# %%
# !python mutag.py --epochs 1000 --lora_dim 4 --hidden_dim 128
# Out:
# Streaming output truncated to the last 5000 lines.
# Test Accuracy 0.7894736842105263
#  17% 167/1000 [00:14<01:23, 10.02it/s]Train MeanLoss 0.37329487562179564
# Train Accuracy 0.8533333333333334
# Val MeanLoss 0.2551848292350769
# Val Accuracy 0.9473684210526315
# Test MeanLoss 0.40947532653808594
# Test Accuracy 0.7894736842105263
#  17% 168/1000 [00:14<01:23,  9.95it/s]Train MeanLoss 0.37123928089936575
# Train Accuracy 0.86
# Val MeanLoss 0.24835099279880524
# Val Accuracy 0.8421052631578947
# Test MeanLoss 0.44087615609169006
# Test Accuracy 0.7894736842105263
#  17% 169/1000 [00:14<01:23,  9.95it/s]Train MeanLoss 0.40757133841514587
# Train Accuracy 0.8533333333333334
# Val MeanLoss 0.20966647565364838
# Val Accuracy 0.8947368421052632
# Test MeanLoss 0.4829234480857849
# Test Accuracy 0.7894736842105263
# Train MeanLoss 0.4543097829818726
# Train Accuracy 0.82
# Val MeanLoss 0.20099429786205292
# Val Accuracy 0.9473684210526315
# Test MeanLoss 0.4579003155231476
# ...

# %%
# !python mutag.py --epochs 1000 --num_blocks 4 --hidden_dim 128
# Out:
# Streaming output truncated to the last 5000 lines.
# Test Accuracy 0.7894736842105263
#  17% 167/1000 [00:12<00:54, 15.30it/s]Train MeanLoss 0.41574356993039446
# Train Accuracy 0.8333333333333334
# Val MeanLoss 0.4561394155025482
# Val Accuracy 0.7894736842105263
# Test MeanLoss 0.30913543701171875
# Test Accuracy 0.7894736842105263
# Train MeanLoss 0.41565914312998453
# Train Accuracy 0.8066666666666666
# Val MeanLoss 0.45225679874420166
# Val Accuracy 0.7894736842105263
# Test MeanLoss 0.3042856454849243
# Test Accuracy 0.7894736842105263
#  17% 169/1000 [00:12<00:53, 15.51it/s]Train MeanLoss 0.40352667689323424
# Train Accuracy 0.8066666666666666
# Val MeanLoss 0.45334529876708984
# Val Accuracy 0.7894736842105263
# Test MeanLoss 0.2954067587852478
# Test Accuracy 0.7894736842105263
# Train MeanLoss 0.3917817044258118
# Train Accuracy 0.8533333333333334
# Val MeanLoss 0.45422136783599854
# Val Accuracy 0.7894736842105263
# Test MeanLoss 0.2925565242767334
# ...

# %%
# !python mutag.py --epochs 1000 --num_bases 1 --hidden_dim 128
# Out:
# Streaming output truncated to the last 5000 lines.
# Test Accuracy 0.7894736842105263
#  17% 167/1000 [00:26<02:08,  6.50it/s]Train MeanLoss 0.4626561188697815
# Train Accuracy 0.8066666666666666
# Val MeanLoss 0.43627557158470154
# Val Accuracy 0.8421052631578947
# Test MeanLoss 0.4604656994342804
# Test Accuracy 0.7894736842105263
#  17% 168/1000 [00:26<02:08,  6.50it/s]Train MeanLoss 0.4618420044581095
# Train Accuracy 0.8066666666666666
# Val MeanLoss 0.43479737639427185
# Val Accuracy 0.8421052631578947
# Test MeanLoss 0.4580741226673126
# Test Accuracy 0.7894736842105263
#  17% 169/1000 [00:26<02:07,  6.50it/s]Train MeanLoss 0.4842993199825287
# Train Accuracy 0.82
# Val MeanLoss 0.41647472977638245
# Val Accuracy 0.8421052631578947
# Test MeanLoss 0.45088186860084534
# Test Accuracy 0.8421052631578947
#  17% 170/1000 [00:26<02:07,  6.50it/s]Train MeanLoss 0.48493653019269306
# Train Accuracy 0.7933333333333333
# Val MeanLoss 0.4040001630783081
# ...

# %%
import matplotlib.pyplot as plt

# Data for the models
models = {
    "full_rank": {"best_test_acc": 0.8421052631578947, "num_params": 516097},
    "blks_4": {"best_test_acc": 0.8421052631578947, "num_params": 221185},
    "bases_1": {"best_test_acc": 0.8947368421052632, "num_params": 221209},
    "lora_dim": {"best_test_acc": 0.8421052631578947, "num_params": 245761}
}

# Extracting data for plotting
num_params = [model["num_params"] for model in models.values()]
test_acc = [model["best_test_acc"] for model in models.values()]
model_names = list(models.keys())

# Assign unique colors to each model
colors = ['red', 'green', 'blue', 'orange']

# Creating the scatter plot with different colors
plt.figure(figsize=(10, 6))
for i, name in enumerate(model_names):
    plt.scatter(num_params[i], test_acc[i], color=colors[i], s=100, label=name, alpha=0.7)

# Adding legend
plt.legend(title="Models", fontsize=12)

# Labeling axes
plt.xlabel("Number of Parameters", fontsize=14)
plt.ylabel("Test Accuracy", fontsize=14)
plt.title("Model Performance vs Number of Parameters", fontsize=16)
plt.grid(alpha=0.3)
plt.show()

# %%
# Calculating Performance Efficiency for each model
performance_efficiency = [model["best_test_acc"] / model["num_params"] for model in models.values()]

# Creating a bar plot for Performance Efficiency
plt.figure(figsize=(10, 6))
plt.bar(model_names, performance_efficiency, color=colors, alpha=0.7)

# Labeling axes and title
plt.xlabel("Models", fontsize=14)
plt.ylabel("Performance Efficiency (Accuracy / Parameters)", fontsize=14)
plt.title("Performance Efficiency of Models", fontsize=16)
plt.grid(axis='y', alpha=0.3)
plt.show()
