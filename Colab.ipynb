# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# PAT = # PUT YOUR PERSONAL ACCESS TOKEN HERE
# !git clone https://sergiogcharles:{PAT}@github.com/alessing/protein-func.git

# %%
import os

path = '/content/drive/MyDrive/Stanford/protein-func'
os.chdir(path)

# %%
# !ls
# Out:
# Colab.ipynb		environment.yml       model		  README.md
# condacolab_install.log	f1_plot.py	      models.py		  requirements.txt
# data			main.py		      processing_scripts  run_scripts
# dataloader.py		make_hdf5_dataset.py  __pycache__	  temp_proteins

# %%
# !pip install -q condacolab
import condacolab
# condacolab.install() # expect a kernel restart
# !mamba env update -n base -f environment.yml
# Out:
# pytorch/linux-64                                            Using cache
# pytorch/noarch                                              Using cache
# nvidia/linux-64                                             Using cache
# nvidia/noarch                                               Using cache
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pyg/linux-64        ⣾
# pyg/noarch          ⣾
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾  pkgs/main/linux-64                                            No change
# [+] 0.1s
# pyg/linux-64      ⣾
# pyg/noarch        ⣾
# pkgs/main/noarch  ⣾
# pkgs/r/linux-64   ⣾
# pkgs/r/noarch     ⣾  pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
# [+] 0.2s
# pyg/linux-64  ⣾
# pyg/noarch    ⣾  pyg/noarch                                                    No change
# pyg/linux-64                                                  No change
#
#
# Looking for: ['python=3.10', 'scikit-learn', 'tensorboard', 'numpy', 'h5py', 'torch-scatter', 'pandas', 'pytorch', 'pytorch-cuda=12.4', 'pyg', 'pip']
#
#
#
#   Pinned packages:
#
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - torch-scatter
#    - python=3.10
#    - scikit-learn
#    - tensorboard
#    - numpy
#    - h5py
#    - pandas
#    - pytorch
#    - pytorch-cuda=12.4
#    - pyg
#    - pip
#
#
#   Package           Version  Build                      Channel           Size
# ────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────
#
#   + libblas           3.9.0  16_linux64_openblas        conda-forge       13kB
#   + llvm-openmp      19.1.5  h024ca30_0                 conda-forge        3MB
#   + libcblas          3.9.0  16_linux64_openblas        conda-forge       13kB
#   + libgcc           14.2.0  h77fa898_1                 conda-forge      849kB
#   + libuv            1.49.2  hb9d3cd8_0                 conda-forge      885kB
#   + libstdcxx        14.2.0  hc0a3c3a_1                 conda-forge        4MB
#   + sleef               3.7  h1b44611_2                 conda-forge        2MB
#   + tbb            2021.8.0  hdb19cb5_0                 pkgs/main          2MB
#   + mkl            2023.2.0  h84fe81f_50496             conda-forge      164MB
#   + libtorch          2.4.1  cpu_mkl_he3c781b_100       conda-forge       52MB
#   + torch-scatter     2.1.1  py310hbf964fc_9            conda-forge      259kB
#
#   Change:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - _openmp_mutex       4.5  2_gnu                      conda-forge     Cached
#   + _openmp_mutex       4.5  2_kmp_llvm                 conda-forge        6kB
#   - pyg               2.6.1  py310_torch_2.3.0_cpu      pyg             Cached
#   + pyg               2.6.1  py310_torch_2.4.0_cu124    pyg                1MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - libgomp          13.2.0  h807b86a_3                 conda-forge     Cached
#   + libgomp          14.2.0  h77fa898_1                 conda-forge      461kB
#   - libgcc-ng        13.2.0  h807b86a_3                 conda-forge     Cached
#   + libgcc-ng        14.2.0  h69a702a_1                 conda-forge       54kB
#   - numpy-base       1.26.4  py310h8a23956_0            pkgs/main       Cached
#   + numpy-base        2.1.3  py310h8a23956_0            pkgs/main          8MB
#   - numpy            1.26.4  py310heeff2f4_0            pkgs/main       Cached
#   + numpy             2.1.3  py310heeff2f4_0            pkgs/main         11kB
#   - scikit-learn      1.5.1  py310h1128e8f_0            pkgs/main       Cached
#   + scikit-learn      1.5.2  py310h27f47ee_1            conda-forge        9MB
#   - pytorch           2.3.1  cpu_py310h4f03144_0        pkgs/main       Cached
#   + pytorch           2.4.1  cpu_mkl_py310h1581fbd_100  conda-forge       32MB
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - networkx            3.3  py310h06a4308_0            pkgs/main       Cached
#   + networkx          3.2.1  py310h06a4308_0            pkgs/main          3MB
#
#   Summary:
#
#   Install: 11 packages
#   Change: 2 packages
#   Upgrade: 6 packages
#   Downgrade: 1 packages
#
#   Total download: 283MB
#
# ────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%_openmp_mutex                                        5.7kB @  56.4kB/s  0.1s
# libblas                                             12.9kB @ 107.6kB/s  0.1s
# libgomp                                            461.0kB @   3.1MB/s  0.1s
# libcblas                                            12.8kB @  81.0kB/s  0.2s
# [+] 0.2s
# Downloading  (5)   1%
# Extracting   (3)  ⣾  llvm-openmp                                          3.2MB @  12.6MB/s  0.3s
# numpy                                               11.2kB @  41.0kB/s  0.2s
# [+] 0.3s
# Downloading  (5)   3%
# Extracting   (4)  ⣾  sleef                                                1.9MB @   5.4MB/s  0.1s
# [+] 0.4s
# Downloading  (5)   8%
# Extracting   (3)  ⣾  networkx                                             2.5MB @   6.5MB/s  0.3s
# torch-scatter                                      259.0kB @ 582.4kB/s  0.1s
# [+] 0.5s
# Downloading  (5)  10%
# Extracting   (4)  ⣾  libgcc-ng                                           54.1kB @  93.6kB/s  0.2s
# [+] 0.6s
# Downloading  (5)  13%
# Extracting   (3)  ⣾  [+] 0.7s
# Downloading  (5)  16%
# Extracting   (4)  ⣾  [+] 0.8s
# Downloading  (5)  20%
# Extracting   (3)  ⣾  scikit-learn                                         9.2MB @  11.4MB/s  0.4s
# pyg                                                  1.5MB @   1.8MB/s  0.7s
# libstdcxx                                            3.9MB @   4.6MB/s  0.2s
# [+] 0.9s
# Downloading  (5)  22%
# Extracting   (6)  ⣾  libuv                                              884.6kB @ 952.9kB/s  0.1s
# [+] 1.0s
# Downloading  (4)  25%
# Extracting   (6)  ⣾  libgcc                                             848.7kB @ 842.7kB/s  0.2s
# [+] 1.1s
# Downloading  (5)  27%
# Extracting   (7)  ⣾  [+] 1.2s
# Downloading  (5)  28%
# Extracting   (7)  ⣾  [+] 1.3s
# Downloading  (5)  30%
# Extracting   (5)  ⣾  [+] 1.4s
# Downloading  (5)  31%
# Extracting   (5)  ⣾  [+] 1.5s
# Downloading  (5)  33%
# Extracting   (5)  ⣾  [+] 1.6s
# Downloading  (5)  35%
# Extracting   (5)  ⣾  [+] 1.7s
# Downloading  (5)  38%
# Extracting   (4)  ⣾  tbb                                                  1.7MB @ 997.8kB/s  0.7s
# [+] 1.8s
# Downloading  (4)  40%
# Extracting   (5)  ⣾  [+] 1.9s
# Downloading  (4)  42%
# Extracting   (5)  ⣾  libtorch                                            51.8MB @  27.5MB/s  1.8s
# [+] 2.0s
# Downloading  (3)  44%
# Extracting   (6)  ⣾  numpy-base                                           8.4MB @   4.0MB/s  1.1s
# [+] 2.1s
# Downloading  (2)  47%
# Extracting   (7)  ⣾  [+] 2.2s
# Downloading  (2)  49%
# Extracting   (7)  ⣾  [+] 2.3s
# Downloading  (2)  51%
# Extracting   (7)  ⣾  [+] 2.4s
# Downloading  (2)  54%
# Extracting   (7)  ⣾  pytorch                                             32.4MB @  13.3MB/s  1.6s
# [+] 2.5s
# Downloading  (1)  57%
# Extracting   (8)  ⣾  [+] 2.6s
# Downloading  (1)  58%
# Extracting   (8)  ⣾  [+] 2.7s
# Downloading  (1)  62%
# Extracting   (8)  ⣾  [+] 2.8s
# Downloading  (1)  64%
# Extracting   (8)  ⣾  [+] 2.9s
# Downloading  (1)  65%
# Extracting   (8)  ⣾  [+] 3.0s
# Downloading  (1)  68%
# Extracting   (8)  ⣾  [+] 3.1s
# Downloading  (1)  69%
# Extracting   (8)  ⣾  [+] 3.2s
# Downloading  (1)  72%
# Extracting   (7)  ⣾  [+] 3.3s
# Downloading  (1)  75%
# Extracting   (7)  ⣾  [+] 3.4s
# Downloading  (1)  77%
# Extracting   (6)  ⣾  [+] 3.5s
# Downloading  (1)  80%
# Extracting   (6)  ⣾  [+] 3.6s
# Downloading  (1)  83%
# Extracting   (6)  ⣾  [+] 3.7s
# Downloading  (1)  86%
# Extracting   (6)  ⣾  [+] 3.8s
# Downloading  (1)  87%
# Extracting   (6)  ⣾  [+] 3.9s
# Downloading  (1)  90%
# Extracting   (6)  ⣾  [+] 4.0s
# Downloading  (1)  92%
# Extracting   (5)  ⣾  [+] 4.1s
# Downloading  (1)  96%
# Extracting   (5)  ⣾  [+] 4.2s
# Downloading  (1)  99%
# Extracting   (5)  ⣾  [+] 4.3s
# Downloading  (1)  99%
# Extracting   (5)  ⣾  mkl                                                164.4MB @  37.4MB/s  4.1s
# [+] 4.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.0s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.1s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.2s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.3s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 13.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.4s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
# | Ran pip subprocess with arguments:
# ['/usr/local/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Requirement already satisfied: biopython in /usr/local/lib/python3.10/site-packages (from -r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 1)) (1.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/site-packages (from -r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (3.9.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/site-packages (from -r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 3)) (3.2.1)
# Collecting networkx (from -r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 3))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/site-packages (from -r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 4)) (3.12.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (from biopython->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/site-packages (from matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->-r /content/drive/MyDrive/Stanford/protein-func/condaenv.9hd0jplq.requirements.txt (line 2)) (1.16.0)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Installing collected packages: networkx
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
# Successfully installed networkx-3.4.2
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate base
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
import torch

# %%
# !ls
# Out:
# Colab.ipynb		environment.yml       model		  README.md
# condacolab_install.log	f1_plot.py	      models.py		  requirements.txt
# data			main.py		      processing_scripts  run_scripts
# dataloader.py		make_hdf5_dataset.py  __pycache__	  temp_proteins

# %%
# !python main.py
# Out:
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Stanford/protein-func/main.py", line 417, in <module>
#     main()
#   File "/content/drive/MyDrive/Stanford/protein-func/main.py", line 183, in main
#     train_data, temp_data = train_test_split(
#   File "/usr/local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/site-packages/sklearn/model_selection/_split.py", line 2785, in train_test_split
#     n_train, n_test = _validate_shuffle_split(
#   File "/usr/local/lib/python3.10/site-packages/sklearn/model_selection/_split.py", line 2415, in _validate_shuffle_split
#     raise ValueError(
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.
